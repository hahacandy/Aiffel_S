# %% [markdown]
# # 파이썬으로 그래프 그리기

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")

# 보여주기
plt.savefig('./barplot.png')  # 그래프를 이미지로 출력
plt.show()                            # 그래프를 화면으로 출력

# %% [markdown]
# # 처음부터 순서대로

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# %% [markdown]
# %matplotlib inline 은 파이썬에서 사용하는 매직메소드라고 하며 rich output 에 대한 표현방식이라고 핞다.
# 그래프와 같은 그림, 소리 애니메이션 과 같은 결과물을 rich output라고 하는듯
# 여기서는 그래프 출력을 위해 사용
# 매직메소드에 대해 자세히는 https://studymake.tistory.com/601

# %%
# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# %%
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(1,1,1)

# %% [markdown]
# figsize=(10,10)
# 10、10あれはグラフの大きさを決める引数
# でもグラブのxとyの数値は0~1.0だ。
# あれはじっさいのプロットの数値によって変わるらしい。

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

# %% [markdown]
# fig.add_subplot(2,2,1)
# 一つ目の引数はy軸、つまり縦の空間を2に割る。
# 二つ目の引数はxの軸、横
# そして三つ目は割った空間いどこに置くかの引数
#
# このグラフ左下に置きたいなら、
# ax4 = fig.add_subplot(2,2,3)
# これを追加したらできる。

# %%
#그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 実際の数値を持ってグラフを描画する。

# %%
#그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")
# Out:
# Text(0.5, 1.0, "Yuna's Test Result")
