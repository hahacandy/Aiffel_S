# %% [markdown]
# # 20-4.인터넷과 프로토콜 (3) 소켓 통신

# %%
import socket
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:     # 소켓 s를 하나 열어서
    s.connect(('www.google.com', 80))          # www.google.com 이라는 호스트의 80번 포트에 접속합니다. 
    cmd = 'GET http://www.google.com HTTP/1.0\r\n\r\n'.encode() 
    s.send(cmd)                 # 접속이 되면 GET xxxxx 형식의 HTTP 프로토콜로 된 명령을 전송합니다. 
    data = s.recv(1024)    # 그리고 1024바이트만큼의 HTTP 응답을 수신합니다. 
print('Received:', data)  # 어떤 응답을 수신했는지 볼까요?
# Out:
# Received: b'HTTP/1.0 404 Not Found\r\nContent-Type: text/html; charset=UTF-8\r\nDate: Wed, 17 Feb 2021 01:49:14 GMT\r\nServer: gws\r\nContent-Length: 1561\r\nX-XSS-Protection: 0\r\nX-Frame-Options: SAMEORIGIN\r\n\r\n<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resoluti'

# %% [markdown]
# # 20-9.API 이용하기 (4) 날씨 API 사용하기

# %%
import requests
myapi = "af44a23b3fa31260fd92b236a65bffa3"

#lat: 위도, #lon:경도
def makeurl(lat, lng):
    url = "https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&appid={}".format(lat, lng, myapi)
    return url

response = requests.get(makeurl(37,127))
weather = response.json()
weather
# Out:
# {'lat': 37,
#  'lon': 127,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400,
#  'current': {'dt': 1613526555,
#   'sunrise': 1613513930,
#   'sunset': 1613553210,
#   'temp': 265.15,
#   'feels_like': 255.05,
#   'pressure': 1020,
#   'humidity': 67,
#   'dew_point': 260.65,
#   'uvi': 1.97,
#   'clouds': 75,
#   'visibility': 10000,
#   'wind_speed': 9.77,
#   'wind_deg': 320,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1613526600, 'precipitation': 0},
#   {'dt': 1613526660, 'precipitation': 0},
#   {'dt': 1613526720, 'precipitation': 0},
#   {'dt': 1613526780, 'precipitation': 0},
#   {'dt': 1613526840, 'precipitation': 0},
#   {'dt': 1613526900, 'precipitation': 0},
#   {'dt': 1613526960, 'precipitation': 0},
#   {'dt': 1613527020, 'precipitation': 0},
#   {'dt': 1613527080, 'precipitation': 0},
#   {'dt': 1613527140, 'precipitation': 0},
#   {'dt': 1613527200, 'precipitation': 0},
#   {'dt': 1613527260, 'precipitation': 0},
#   {'dt': 1613527320, 'precipitation': 0},
#   {'dt': 1613527380, 'precipitation': 0},
#   {'dt': 1613527440, 'precipitation': 0},
#   {'dt': 1613527500, 'precipitation': 0},
#   {'dt': 1613527560, 'precipitation': 0},
#   {'dt': 1613527620, 'precipitation': 0},
#   {'dt': 1613527680, 'precipitation': 0},
#   {'dt': 1613527740, 'precipitation': 0},
#   {'dt': 1613527800, 'precipitation': 0},
#   {'dt': 1613527860, 'precipitation': 0},
#   {'dt': 1613527920, 'precipitation': 0},
#   {'dt': 1613527980, 'precipitation': 0},
#   {'dt': 1613528040, 'precipitation': 0},
#   {'dt': 1613528100, 'precipitation': 0},
#   {'dt': 1613528160, 'precipitation': 0},
#   {'dt': 1613528220, 'precipitation': 0},
#   {'dt': 1613528280, 'precipitation': 0},
#   {'dt': 1613528340, 'precipitation': 0},
#   {'dt': 1613528400, 'precipitation': 0},
#   {'dt': 1613528460, 'precipitation': 0},
#   {'dt': 1613528520, 'precipitation': 0},
#   {'dt': 1613528580, 'precipitation': 0},
#   {'dt': 1613528640, 'precipitation': 0},
#   {'dt': 1613528700, 'precipitation': 0},
#   {'dt': 1613528760, 'precipitation': 0},
#   {'dt': 1613528820, 'precipitation': 0},
#   {'dt': 1613528880, 'precipitation': 0},
#   {'dt': 1613528940, 'precipitation': 0},
#   {'dt': 1613529000, 'precipitation': 0},
#   {'dt': 1613529060, 'precipitation': 0},
#   {'dt': 1613529120, 'precipitation': 0},
#   {'dt': 1613529180, 'precipitation': 0},
#   {'dt': 1613529240, 'precipitation': 0},
#   {'dt': 1613529300, 'precipitation': 0},
#   {'dt': 1613529360, 'precipitation': 0},
#   {'dt': 1613529420, 'precipitation': 0},
#   {'dt': 1613529480, 'precipitation': 0},
#   {'dt': 1613529540, 'precipitation': 0},
#   {'dt': 1613529600, 'precipitation': 0},
#   {'dt': 1613529660, 'precipitation': 0},
#   {'dt': 1613529720, 'precipitation': 0},
#   {'dt': 1613529780, 'precipitation': 0},
#   {'dt': 1613529840, 'precipitation': 0},
#   {'dt': 1613529900, 'precipitation': 0},
#   {'dt': 1613529960, 'precipitation': 0},
#   {'dt': 1613530020, 'precipitation': 0},
#   {'dt': 1613530080, 'precipitation': 0},
#   {'dt': 1613530140, 'precipitation': 0},
#   {'dt': 1613530200, 'precipitation': 0}],
#  'hourly': [{'dt': 1613523600,
#    'temp': 265.15,
#    'feels_like': 254.83,
#    'pressure': 1020,
#    'humidity': 67,
#    'dew_point': 260.65,
#    'uvi': 1.26,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 10.09,
#    'wind_deg': 311,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.2},
#   {'dt': 1613527200,
#    'temp': 265.59,
#    'feels_like': 255.62,
#    'pressure': 1020,
#    'humidity': 75,
#    'dew_point': 262.33,
#    'uvi': 1.97,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 9.75,
#    'wind_deg': 308,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.24},
#   {'dt': 1613530800,
#    'temp': 266.26,
#    'feels_like': 256.24,
#    'pressure': 1018,
#    'humidity': 78,
#    'dew_point': 263.43,
#    'uvi': 2.42,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 9.94,
#    'wind_deg': 307,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.2},
#   {'dt': 1613534400,
#    'temp': 266.98,
#    'feels_like': 256.7,
#    'pressure': 1018,
#    'humidity': 80,
#    'dew_point': 264.42,
#    'uvi': 2.47,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 10.42,
#    'wind_deg': 305,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.08},
#   {'dt': 1613538000,
#    'temp': 267.41,
#    'feels_like': 256.89,
#    'pressure': 1017,
#    'humidity': 79,
#    'dew_point': 264.7,
#    'uvi': 2.04,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 10.8,
#    'wind_deg': 305,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1613541600,
#    'temp': 267.56,
#    'feels_like': 256.96,
#    'pressure': 1017,
#    'humidity': 80,
#    'dew_point': 258.07,
#    'uvi': 1.33,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 10.95,
#    'wind_deg': 303,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1613545200,
#    'temp': 267.49,
#    'feels_like': 256.94,
#    'pressure': 1017,
#    'humidity': 81,
#    'dew_point': 258.54,
#    'uvi': 0.69,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 10.88,
#    'wind_deg': 303,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1613548800,
#    'temp': 267.04,
#    'feels_like': 256.5,
#    'pressure': 1018,
#    'humidity': 83,
#    'dew_point': 259.08,
#    'uvi': 0.2,
#    'clouds': 38,
#    'visibility': 10000,
#    'wind_speed': 10.86,
#    'wind_deg': 302,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613552400,
#    'temp': 266.44,
#    'feels_like': 256.1,
#    'pressure': 1018,
#    'humidity': 83,
#    'dew_point': 259,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 10.5,
#    'wind_deg': 301,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613556000,
#    'temp': 266.15,
#    'feels_like': 256.21,
#    'pressure': 1019,
#    'humidity': 85,
#    'dew_point': 259.39,
#    'uvi': 0,
#    'clouds': 38,
#    'visibility': 10000,
#    'wind_speed': 9.94,
#    'wind_deg': 304,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1613559600,
#    'temp': 266.08,
#    'feels_like': 256.33,
#    'pressure': 1019,
#    'humidity': 84,
#    'dew_point': 259.16,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 9.64,
#    'wind_deg': 310,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1613563200,
#    'temp': 265.97,
#    'feels_like': 256.73,
#    'pressure': 1019,
#    'humidity': 85,
#    'dew_point': 259.3,
#    'uvi': 0,
#    'clouds': 57,
#    'visibility': 10000,
#    'wind_speed': 8.91,
#    'wind_deg': 312,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613566800,
#    'temp': 265.99,
#    'feels_like': 256.76,
#    'pressure': 1020,
#    'humidity': 84,
#    'dew_point': 258.74,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.88,
#    'wind_deg': 317,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613570400,
#    'temp': 265.78,
#    'feels_like': 256.63,
#    'pressure': 1020,
#    'humidity': 82,
#    'dew_point': 257.98,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.72,
#    'wind_deg': 318,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613574000,
#    'temp': 265.6,
#    'feels_like': 256.77,
#    'pressure': 1020,
#    'humidity': 83,
#    'dew_point': 258.12,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 8.26,
#    'wind_deg': 317,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613577600,
#    'temp': 265.58,
#    'feels_like': 256.87,
#    'pressure': 1020,
#    'humidity': 84,
#    'dew_point': 258.39,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 8.1,
#    'wind_deg': 315,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613581200,
#    'temp': 265.48,
#    'feels_like': 256.99,
#    'pressure': 1020,
#    'humidity': 83,
#    'dew_point': 258.19,
#    'uvi': 0,
#    'clouds': 84,
#    'visibility': 10000,
#    'wind_speed': 7.76,
#    'wind_deg': 317,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613584800,
#    'temp': 265.5,
#    'feels_like': 257.54,
#    'pressure': 1020,
#    'humidity': 85,
#    'dew_point': 258.78,
#    'uvi': 0,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 7.03,
#    'wind_deg': 316,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613588400,
#    'temp': 265.36,
#    'feels_like': 257.56,
#    'pressure': 1020,
#    'humidity': 84,
#    'dew_point': 258.51,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 6.78,
#    'wind_deg': 321,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613592000,
#    'temp': 265.19,
#    'feels_like': 257.43,
#    'pressure': 1020,
#    'humidity': 83,
#    'dew_point': 257.94,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 6.68,
#    'wind_deg': 326,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613595600,
#    'temp': 265.14,
#    'feels_like': 257.46,
#    'pressure': 1020,
#    'humidity': 83,
#    'dew_point': 257.56,
#    'uvi': 0,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 6.56,
#    'wind_deg': 325,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613599200,
#    'temp': 265.16,
#    'feels_like': 258.18,
#    'pressure': 1021,
#    'humidity': 83,
#    'dew_point': 257.88,
#    'uvi': 0,
#    'clouds': 91,
#    'visibility': 10000,
#    'wind_speed': 5.57,
#    'wind_deg': 328,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1613602800,
#    'temp': 265.41,
#    'feels_like': 258.56,
#    'pressure': 1021,
#    'humidity': 82,
#    'dew_point': 257.5,
#    'uvi': 0.19,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 5.39,
#    'wind_deg': 335,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1613606400,
#    'temp': 266.41,
#    'feels_like': 258.5,
#    'pressure': 1021,
#    'humidity': 80,
#    'dew_point': 257.24,
#    'uvi': 0.71,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 6.97,
#    'wind_deg': 331,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1613610000,
#    'temp': 267.16,
#    'feels_like': 259.1,
#    'pressure': 1022,
#    'humidity': 79,
#    'dew_point': 257.51,
#    'uvi': 1.52,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 7.25,
#    'wind_deg': 327,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1613613600,
#    'temp': 268.08,
#    'feels_like': 260.06,
#    'pressure': 1022,
#    'humidity': 79,
#    'dew_point': 258.04,
#    'uvi': 2.39,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 7.3,
#    'wind_deg': 324,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613617200,
#    'temp': 269.02,
#    'feels_like': 261.19,
#    'pressure': 1021,
#    'humidity': 78,
#    'dew_point': 258.55,
#    'uvi': 2.94,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 7.12,
#    'wind_deg': 322,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613620800,
#    'temp': 269.95,
#    'feels_like': 262.37,
#    'pressure': 1021,
#    'humidity': 78,
#    'dew_point': 259.1,
#    'uvi': 2.97,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 6.89,
#    'wind_deg': 318,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613624400,
#    'temp': 270.58,
#    'feels_like': 263.04,
#    'pressure': 1021,
#    'humidity': 78,
#    'dew_point': 259.43,
#    'uvi': 2.45,
#    'clouds': 27,
#    'visibility': 10000,
#    'wind_speed': 6.91,
#    'wind_deg': 316,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613628000,
#    'temp': 271.04,
#    'feels_like': 263.87,
#    'pressure': 1020,
#    'humidity': 78,
#    'dew_point': 259.93,
#    'uvi': 1.58,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 6.45,
#    'wind_deg': 315,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1613631600,
#    'temp': 271.27,
#    'feels_like': 264.41,
#    'pressure': 1021,
#    'humidity': 79,
#    'dew_point': 260.67,
#    'uvi': 0.76,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 6.06,
#    'wind_deg': 313,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1613635200,
#    'temp': 271.07,
#    'feels_like': 264.6,
#    'pressure': 1021,
#    'humidity': 80,
#    'dew_point': 261.01,
#    'uvi': 0.22,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.5,
#    'wind_deg': 311,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1613638800,
#    'temp': 270.14,
#    'feels_like': 265,
#    'pressure': 1022,
#    'humidity': 83,
#    'dew_point': 261.61,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 311,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1613642400,
#    'temp': 269.4,
#    'feels_like': 264.91,
#    'pressure': 1023,
#    'humidity': 84,
#    'dew_point': 261.81,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.54,
#    'wind_deg': 311,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613646000,
#    'temp': 269.26,
#    'feels_like': 265.16,
#    'pressure': 1023,
#    'humidity': 84,
#    'dew_point': 261.71,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.95,
#    'wind_deg': 318,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613649600,
#    'temp': 269.19,
#    'feels_like': 265.53,
#    'pressure': 1023,
#    'humidity': 84,
#    'dew_point': 261.53,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.32,
#    'wind_deg': 319,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613653200,
#    'temp': 269.22,
#    'feels_like': 265.71,
#    'pressure': 1024,
#    'humidity': 85,
#    'dew_point': 261.73,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.13,
#    'wind_deg': 287,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613656800,
#    'temp': 269.28,
#    'feels_like': 265.46,
#    'pressure': 1024,
#    'humidity': 86,
#    'dew_point': 262.63,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.6,
#    'wind_deg': 281,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613660400,
#    'temp': 269.28,
#    'feels_like': 265.5,
#    'pressure': 1024,
#    'humidity': 88,
#    'dew_point': 263.28,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.59,
#    'wind_deg': 285,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613664000,
#    'temp': 269.26,
#    'feels_like': 265.53,
#    'pressure': 1024,
#    'humidity': 88,
#    'dew_point': 263.67,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.51,
#    'wind_deg': 291,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613667600,
#    'temp': 269.31,
#    'feels_like': 265.73,
#    'pressure': 1024,
#    'humidity': 89,
#    'dew_point': 263.75,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.33,
#    'wind_deg': 285,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613671200,
#    'temp': 269.41,
#    'feels_like': 265.99,
#    'pressure': 1023,
#    'humidity': 89,
#    'dew_point': 263.93,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.11,
#    'wind_deg': 273,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613674800,
#    'temp': 269.39,
#    'feels_like': 265.82,
#    'pressure': 1022,
#    'humidity': 89,
#    'dew_point': 264.21,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.32,
#    'wind_deg': 208,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613678400,
#    'temp': 269.08,
#    'feels_like': 264.91,
#    'pressure': 1022,
#    'humidity': 91,
#    'dew_point': 264.87,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.18,
#    'wind_deg': 174,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613682000,
#    'temp': 268.89,
#    'feels_like': 264.43,
#    'pressure': 1022,
#    'humidity': 92,
#    'dew_point': 265.1,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.59,
#    'wind_deg': 160,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613685600,
#    'temp': 268.75,
#    'feels_like': 264.07,
#    'pressure': 1022,
#    'humidity': 92,
#    'dew_point': 265.2,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.88,
#    'wind_deg': 150,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1613689200,
#    'temp': 269.37,
#    'feels_like': 264.72,
#    'pressure': 1022,
#    'humidity': 92,
#    'dew_point': 265.47,
#    'uvi': 0.2,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.93,
#    'wind_deg': 143,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1613692800,
#    'temp': 271.1,
#    'feels_like': 266.29,
#    'pressure': 1021,
#    'humidity': 90,
#    'dew_point': 266.12,
#    'uvi': 0.75,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.38,
#    'wind_deg': 144,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1613530800,
#    'sunrise': 1613513930,
#    'sunset': 1613553210,
#    'temp': {'day': 266.26,
#     'min': 264.96,
#     'max': 268.18,
#     'night': 265.78,
#     'eve': 266.44,
#     'morn': 266.08},
#    'feels_like': {'day': 256.24,
#     'night': 256.63,
#     'eve': 256.1,
#     'morn': 255.88},
#    'pressure': 1018,
#    'humidity': 78,
#    'dew_point': 263.43,
#    'wind_speed': 9.94,
#    'wind_deg': 307,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 95,
#    'pop': 0.32,
#    'snow': 0.13,
#    'uvi': 2.47},
#   {'dt': 1613617200,
#    'sunrise': 1613600260,
#    'sunset': 1613639672,
#    'temp': {'day': 269.02,
#     'min': 265.14,
#     'max': 271.27,
#     'night': 269.28,
#     'eve': 270.14,
#     'morn': 265.14},
#    'feels_like': {'day': 261.19, 'night': 265.46, 'eve': 265, 'morn': 257.46},
#    'pressure': 1021,
#    'humidity': 78,
#    'dew_point': 258.55,
#    'wind_speed': 7.12,
#    'wind_deg': 322,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 34,
#    'pop': 0,
#    'uvi': 2.97},
#   {'dt': 1613703600,
#    'sunrise': 1613686588,
#    'sunset': 1613726134,
#    'temp': {'day': 278.61,
#     'min': 268.75,
#     'max': 281.46,
#     'night': 277.15,
#     'eve': 278.24,
#     'morn': 268.89},
#    'feels_like': {'day': 273.4,
#     'night': 272.34,
#     'eve': 272.92,
#     'morn': 264.43},
#    'pressure': 1019,
#    'humidity': 64,
#    'dew_point': 270.57,
#    'wind_speed': 4.44,
#    'wind_deg': 207,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 3.11},
#   {'dt': 1613790000,
#    'sunrise': 1613772915,
#    'sunset': 1613812596,
#    'temp': {'day': 284.37,
#     'min': 277.2,
#     'max': 285.17,
#     'night': 280.51,
#     'eve': 282.12,
#     'morn': 277.36},
#    'feels_like': {'day': 278.23,
#     'night': 276.64,
#     'eve': 276.73,
#     'morn': 273.75},
#    'pressure': 1008,
#    'humidity': 71,
#    'dew_point': 279.5,
#    'wind_speed': 7.51,
#    'wind_deg': 218,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 98,
#    'pop': 0,
#    'uvi': 3.22},
#   {'dt': 1613876400,
#    'sunrise': 1613859241,
#    'sunset': 1613899057,
#    'temp': {'day': 286.48,
#     'min': 278.76,
#     'max': 287.03,
#     'night': 280.45,
#     'eve': 283.26,
#     'morn': 278.76},
#    'feels_like': {'day': 282.66,
#     'night': 277.74,
#     'eve': 280.24,
#     'morn': 275.95},
#    'pressure': 1007,
#    'humidity': 63,
#    'dew_point': 279.73,
#    'wind_speed': 4.28,
#    'wind_deg': 221,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 4.08},
#   {'dt': 1613962800,
#    'sunrise': 1613945565,
#    'sunset': 1613985518,
#    'temp': {'day': 280.79,
#     'min': 274.69,
#     'max': 280.79,
#     'night': 274.69,
#     'eve': 276.86,
#     'morn': 277.33},
#    'feels_like': {'day': 273.14,
#     'night': 268.07,
#     'eve': 269.47,
#     'morn': 274.19},
#    'pressure': 1020,
#    'humidity': 52,
#    'dew_point': 267.01,
#    'wind_speed': 7.77,
#    'wind_deg': 306,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1614049200,
#    'sunrise': 1614031889,
#    'sunset': 1614071979,
#    'temp': {'day': 277.08,
#     'min': 271.24,
#     'max': 279.63,
#     'night': 275.44,
#     'eve': 277.74,
#     'morn': 271.24},
#    'feels_like': {'day': 273.1,
#     'night': 272.35,
#     'eve': 273.86,
#     'morn': 267.38},
#    'pressure': 1026,
#    'humidity': 53,
#    'dew_point': 257.56,
#    'wind_speed': 1.99,
#    'wind_deg': 51,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 91,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1614135600,
#    'sunrise': 1614118212,
#    'sunset': 1614158439,
#    'temp': {'day': 282.33,
#     'min': 273.94,
#     'max': 283.63,
#     'night': 277.03,
#     'eve': 279.14,
#     'morn': 273.94},
#    'feels_like': {'day': 279.41,
#     'night': 273.56,
#     'eve': 274.58,
#     'morn': 270.46},
#    'pressure': 1024,
#    'humidity': 51,
#    'dew_point': 271.87,
#    'wind_speed': 1.24,
#    'wind_deg': 205,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5}]}

# %% [markdown]
# # 20-10.크롤링 이용하기 (1) 크롤러 만들기

# %%
import urllib
def download(url):
    return urllib.request.urlopen(url)

# %%
from urllib.error import URLError, HTTPError, ContentTooShortError

def download(url):
    try:
        html = urllib.request.urlopen(url)
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error', e.reason)
        html = None
    return html

download('https://www.google.com')

# %%
def download(url):
    try:
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error', e.reason)
        html = None
    return html

# %%
download('https://www.google.com')
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="LPGrHEMA1CtXYrJlETnZFQ==">(function(){window.google={kEI:\'HnYsYOOFJtqQr7wPha2O2Ac\',kEXPI:\'0,1302426,7,56976,954,5105,206,3204,10,1590,925,1391,383,246,5,1354,5250,2342,1120174,1232,1196474,577,328984,51223,16115,28684,9188,8384,4858,1362,3472,5819,3025,4742,12841,4020,978,13228,2054,920,873,399,3793,6430,14528,235,4281,2778,919,2278,7,2796,1593,1279,2212,241,289,149,1103,840,517,1522,158,4100,312,1137,2,2063,606,2023,2297,4176,95,326,1284,2943,5846,3227,2845,7,4773,7581,5096,7877,4928,108,3407,908,2,941,2614,2397,7470,3275,3,346,230,970,865,4625,148,5990,7985,4,1253,275,2304,1236,1145,4081,577,1791,2893,459,1555,4067,1036,4598,1426,2102,3393,1409,344,2658,3903,1,857,912,564,464,656,30,1303,2551,23,3210,1042,3286,2213,1397,690,218,638,1494,605,2,892,591,3177,319,2361,55,3128,2301,54,1307,587,11,731,665,2145,3679,2533,479,138,373,2,1962,777,363,20,47,99,869,2,2101,6,908,3,107,3434,1,3521,2496,488,494,979,1896,186,385,430,231,232,115,3257,1187,627,38,245,38,671,203,3434,1940,624,1254,238,164,134,1,59,598,2,59,306,709,179,941,877,463,82,682,32,368,32,3284,239,46,77,138,250,51,1255,2,77,261,225,262,513,56,176,405,979,525,141,2,39,72,2,68,52,345,654,683,231,26,1312,454,1414,813,101,336,2,84,1199,2759,20,302,551,167,1011,5690857,3870,35,63,8796624,1324,549,333,444,1,2,80,1,900,896,1,9,2,2551,1,748,141,59,736,563,1,4265,1,1,2,1331,3299,248,595,1,2608,155,17,13,72,46,75,6,23,4,6,30,2,13,25,1,11,1,25,1,23957127,4010142,689,590,2,643\',kBL:\'ETbN\'};google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){\ngoogle.h=[];google.g=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.ml=function(){return null};google.log=function(a,b,c,d,f){if(c=google.logUrl(a,b,c,d,f)){a=new Image;var e=google.h,g=google.g;e[g]=a;a.onerror=a.onload=a.onabort=function(){delete e[g]};a.src=c;google.g=g+1}};google.logUrl=function(a,b,c,d,f){var e="";c||-1!=b.search("&ei=")||(e="&ei="+google.getEI(d),-1==b.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!c&&window._cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(d="&cshid="+window._cshid);c=c||"/"+(f||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;po ...

# %%
! pip install bs4
! pip install requests
# Out:
# Requirement already satisfied: bs4 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (from bs4) (4.6.0)
# Requirement already satisfied: requests in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/thuban/anaconda3/envs/aiffel/lib/python3.7/site-packages (from requests) (1.26.2)

# %%
import requests
url = 'http://www.google.com'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
def download2(url):
    try:
        response = requests.get(url)
        html = response.text
    except requests.ConnectionError:
        print('Connection error')
        html = None
    return html

download2('https://www.google.com')
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="OrBZaZTdMNCnqYiCfYZQPA==">(function(){window.google={kEI:\'IXYsYNS3BI-ymAXbyomwCg\',kEXPI:\'0,1359409,954,5105,206,3204,10,1590,2316,383,246,5,1354,5251,2341,4043,1116131,1233,1196428,94,527,328985,51224,16108,17450,11240,9188,8384,4858,1362,9290,3027,4741,12841,4020,978,13228,2054,920,873,4192,6434,14523,4521,2774,919,1832,445,8,2796,1593,1279,2212,530,149,1103,840,517,1522,158,4100,312,1137,2,2063,606,2024,1776,520,4176,93,328,1284,2943,5846,3227,2845,7,4773,7581,5096,7876,3748,1181,108,3407,908,2,941,2614,2397,2650,4818,3277,3,346,230,970,865,4624,149,5990,6324,1661,4,1528,2304,1236,1145,4658,1791,125,4,1660,1104,459,1555,4067,1036,1470,3128,1426,2484,3011,1409,344,2658,3906,1,336,518,912,564,464,656,30,894,279,130,5783,1043,3286,2213,2305,638,1494,605,2,4660,319,2361,55,6790,587,11,731,665,2145,3658,2554,479,142,370,1963,777,4,359,67,99,819,41,2,2111,5,908,3,3541,1,644,4296,1045,92,428,494,2295,766,385,661,347,3257,1187,627,38,245,709,3637,1941,597,20,1260,238,447,509,2,60,1014,179,938,210,1004,211,160,531,423,2858,711,77,139,249,1306,2,77,261,225,263,568,178,403,157,261,415,2,143,527,182,431,107,654,190,494,215,5,36,1235,78,111,236,4,901,561,2,31,21,914,336,2,1283,13,2766,400,5692488,12,3858,35,63,8797948,549,333,444,1,2,80,1,900,896,1,9,2,2551,1,748,141,59,736,563,1,4265,1,1,2,1331,3299,248,595,1,2608,155,17,13,72,46,75,6,23,4,6,30,2,13,25,1,11,1,25,1,23957126,2788966,1221177,936,343,2,254\',kBL:\'ETbN\'};google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){\ngoogle.h=[];google.g=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.ml=function(){return null};google.log=function(a,b,c,d,f){if(c=google.logUrl(a,b,c,d,f)){a=new Image;var e=google.h,g=google.g;e[g]=a;a.onerror=a.onload=a.onabort=function(){delete e[g]};a.src=c;google.g=g+1}};google.logUrl=function(a,b,c,d,f){var e="";c||-1!=b.search("&ei=")||(e="&ei="+google.getEI(d),-1==b.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!c&&window._cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(d="&cshid="+window._cshid);c=c||"/"+(f||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:1 ...

# %%
import requests
from bs4 import BeautifulSoup
html = requests.get('http://www.google.com')
soup = BeautifulSoup(html.text, 'html.parser')

# %%
soup.html.body
# Out:
# <body bgcolor="#fff"><script nonce="N5p2QQ4MSqfaySgtyII2Tw==">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id="gbar"><nobr><b class="gb1">검색</b> <a class="gb1" href="http://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a> <a class="gb1" href="http://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a> <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a> <a class="gb1" href="http://www.youtube.com/?gl=KR&amp;tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a> <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span class="gbi" id="gbn"></span><span class="gbf" id="gbf"></span><span id="gbe"></span><a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a> | <a class="gb4" href="/preferences?hl=ko">설정</a> | <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=http://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">로그인</a></nobr></div><div class="gbh" style="left:0"></div><div class="gbh" style="right:0"></div></div><center><br clear="all" id="lgpd"/><div id="lga"><img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/><br/><br/></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%"> </td><td align="center" nowrap=""><input name="ie" type="hidden" value="ISO-8859-1"/><input name="hl" type="hidden" value="ko"/><input name="source" type="hidden" value="hp"/><input name="biw" type="hidden"/><input name="bih" type="hidden"/><div class="ds" style="height:32px;margin:4px 0"><div style="position:relative;zoom:1"><input autocomplete="off" class="lst tiah" maxlength="2048" name="q" size="57" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000;padding-right:38px" title="Google 검색" value=""/><img alt="" data-script-url="/textinputassistant/11/ko_tia.js" height="23" id="tsuid1" src="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;right:5px;top:4px;z-index:300" width="27"/><script nonce="N5p2QQ4MSqfaySgtyII2Tw==">(function(){var id='tsuid1';document.getElementById(id).onclick = function(){var s = document.createElement('script');s.src = this.getAttribute('data-script-url');(document.getElementById('xjsc')||document.body).appendChild(s);};})();</script></div></div><br style="line-height:0"/><span class="ds"><span class="lsbb"><input class="lsb" name="btnG" type="submit" value="Google 검색"/></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid2" name="btnI" type="submit" value="I’m Feeling Lucky"/><script nonce="N5p2QQ4MSqfaySgtyII2Tw==">(function(){var id='tsuid2';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input name="iflsig" type="hidden" value="AINFCbYAAAAAYCyEMVDv0PVnQw1nEs1FPUdqBvLfHkHO"/></span></span></td><td align="left" class="fl sblc" nowrap="" width="25%"><a href="/advanced_search?hl=ko&amp;authuser=0">고급검색</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"/><script nonce="N5p2QQ4MSqfaySgtyII2Tw==">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br/></div><span id="footer"><div style="font-size:10pt"><div id="WqQANb" style="margin:19px auto;text-align:center"><a href="/intl/ko/ads/">광고 프로그램</a><a href="http://www.google.co.kr/intl/ko/services/">비즈니스 솔루션</a><a href="/intl/ko/about.html">Google 정보</a><a href="http://www.google.com/setprefdomain?prefdom=KR&amp;prev=http://www.google.co.kr/&amp;sig=K_vh7nhf61pI2321EMiT_R6hPQz1g%3D">Google.co.kr</a></div></div><p style="font-size:8pt;color:#70757a">© 2021 - <a href="/intl/ko/policies/privacy/">개인정보처리방침</a> - <a href="/intl/ko/policies/terms/">약관</a></p></span></center><script nonce="N5p2QQ4MSqfaySgtyII2Tw==">(function(){window.google.cdo={height:0,width:0};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","","/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI);}).call(this);})();(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.bQ-SGpI31Us.O/m\x3dsb_he,d/am\x3dAHiCOA/d\x3d1/rs\x3dACT90oFnXANbQSMKEgWzH8Ub34tfM8CvbA';
# var d=this||self,e=/^[\w+/_-]+[=]{0,2}$/,f=null,g=function(a){return(a=a.querySelector&&a.querySelector("script[nonce]"))&&(a=a.nonce||a.getAttribute("nonce"))&&e.test(a)?a:""},h=function(a){return a};var l;var n=function(a,b){this.g=b===m?a:""};n.prototype.toString=function(){return this.g+""};var m={};function p(){var a=u;google.lx=function(){q(a);google.lx=function(){}};google.bx||google.lx()}
# function q(a){var b=document;var c="SCRIPT";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);if(void 0===l){b=null;var k=d.trustedTypes;if(k&&k.createPolicy){try{b=k.createPolicy("goog#html",{createHTML:h,createScript:h,createScriptURL:h})}catch(r){d.console&&d.console.error(r.message)}l=b}else l=b}a=(b=l)?b.createScriptURL(a):a;a=new n(a,m);c.src=a instanceof n&&a.constructor===n?a.g:"type_error:TrustedResourceUrl";(a=c.ownerDocument&&c.ownerDocument.defaultView)&&
# a!=d?a=g(a.document):(null===f&&(f=g(d.document)),a=f);a&&c.setAttribute("nonce",a);google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");document.body.appendChild(c)};setTimeout(function(){p()},0);})();(function(){window.google.xjsu='/xjs/_/js/k\x3dxjs.hp.en.bQ-SGpI31Us.O/m\x3dsb_he,d/am\x3dAHiCOA/d\x3d1/rs\x3dACT90oFnXANbQSMKEgWzH8Ub34tfM8CvbA';})();function _DumpException(e){throw e;}
# function _F_installCss(c){}
# (function(){google.jl={dw:false,em:[],emw:false,lls:'default',pdt:0,snet:true,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22dhqt\x22:true,\x22ds\x22:\x22\x22,\x22ffql\x22:\x22ko\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22isbh\x22:28,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22&#44160;&#49353;&#50612; &#51648;&#50864;&#44592;\x22,\x22dym\x22:\x22&#51060;&#44163;&#51012; &#52286;&#51004;&#49512;&#45208;&#50836;?\x22,\x22lcky\x22:\x22I&#8217;m Feeling Lucky\x22,\x22lml\x22:\x22&#51088;&#49464;&#55176; &#50508;&#50500;&#48372;&#44592;\x22,\x22oskt\x22:\x22&#51077;&#47141; &#46020;&#44396;\x22,\x22psrc\x22:\x22&#44160;&#49353;&#50612;&#44032; \\u003Ca href\x3d\\\x22/history\\\x22\\u003E&#50937; &#44592;&#47197;\\u003C/a\\u003E&#50640;&#49436; &#49325;&#51228;&#46104;&#50632;&#49845;&#45768;&#45796;.\x22,\x22psrl\x22:\x22&#49325;&#51228;\x22,\x22sbit\x22:\x22&#51060;&#48120;&#51648;&#47196; &#44160;&#49353;\x22,\x22srch\x22:\x22Google &#44160;&#49353;\x22},\x22nrft\x22:false,\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22refpd\x22:true,\x22refspre\x22:true,\x22rfs\x22:[],\x22sbas\x22:\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\x22,\x22sbpl\x22:16,\x22sbpr\x22:16,\x22scd\x22:10,\x22stok\x22:\x227KjtJttO1H_kqz-hXHI2nkdgcKY\x22,\x22uhde\x22:false}}';google.pmc=JSON.parse(pmc);})();</script> </body>

# %%
soup = BeautifulSoup("<span>Wow it's so good!!</span>", 'html.parser')
soup.span
# Out:
# <span>Wow it's so good!!</span>

# %%
# ''', """ 는 여러줄의 문자열을 입력할 때 사용
html='''<title>Fundamental</title> 
         <body>
          <p id='programming'>python</p> 
          <p id='programming'>java</p> 
          <p id='algorithm'>algorithm</p> 
          <p id='fundamental'>math</p> 
          <p id='programming'>C++</p> 
          </body>'''
soup = BeautifulSoup(html, 'html.parser')
soup.findAll({'p'})
# Out:
# [<p id="programming">python</p>,
#  <p id="programming">java</p>,
#  <p id="algorithm">algorithm</p>,
#  <p id="fundamental">math</p>,
#  <p id="programming">C++</p>]

# %%
soup.findAll('p', id='programming')
# Out:
# [<p id="programming">python</p>,
#  <p id="programming">java</p>,
#  <p id="programming">C++</p>]

# %% [markdown]
# # 20-11.크롤링 이용하기 (2) 환율 가져오기

# %%
from bs4 import BeautifulSoup
import requests

#URL 가져오기
url = 'https://m.stock.naver.com/marketindex/index.nhn'
response = requests.get(url)

#Soup 객체 생성
soup = BeautifulSoup(response.text, 'html.parser')

#원하는 데이터 추출 - 국가
country = []
country_1 = soup.findAll('strong', {'class':'stock_item'})
country_2 = soup.findAll('span', {'class':'stock_item'})
for c in country_1:
    country.append(c.text)
for c in country_2:
    country.append(c.text)

#원하는 데이터 추출 - 환율정보
price = []
price_0 = soup.findAll('span', {"class":"stock_price"})
for p in price_0:
    price.append(p.text)

#데이터 정렬, (pandas)
import pandas as pd
data = {}
for i in range(len(country)):
    data[country[i]] = price[i]

pd.Series(data)
# Out:
# 미국 USD        1,107.20
# 유럽 EUR        1,338.94
# 일본 JPY        1,044.09
# 중국 CNY          172.19
# 국제금           1,797.20
# 유가 WTI           60.05
# 달러인덱스            90.50
# 남아프리카 ZAR        75.32
# 노르웨이 NOK        130.62
# 뉴질랜드 NZD        796.74
# 대만 TWD           39.56
# 덴마크 DKK         180.04
# 러시아 RUB          15.02
# 말레이시아 MYR       273.89
# 멕시코 MXN          54.76
# 몽골 MNT            0.39
# 바레인 BHD       2,936.87
# 방글라데시 BDT        13.10
# 베트남 VND           4.82
# 브라질 BRL         206.15
# 브루나이 BND        833.39
# 사우디 SAR         295.17
# 스웨덴 SEK         133.26
# 스위스 CHF       1,239.59
# 싱가포르 SGD        833.39
# 아랍에미리트 AED      301.43
# 영국 GBP        1,536.18
# 오만 OMR        2,875.92
# 요르단 JOD       1,561.64
# 이스라엘 ILS        341.74
# 이집트 EGP          70.88
# 인도 INR           15.18
# 인도네시아 IDR         7.97
# 체코 CZK           51.79
# 칠레 CLP            1.54
# 카자흐스탄 KZT         2.66
# 카타르 QAR         304.09
# 캐나다 CAD         871.37
# 쿠웨이트 KWD      3,659.92
# 태국 THB           36.94
# 터키 TRY          158.43
# 파키스탄 PKR          6.92
# 폴란드 PLN         297.31
# 필리핀 PHP          22.88
# 헝가리 HUF           3.73
# 호주 AUD          857.64
# 홍콩 HKD          142.81
# dtype: object

# %% [markdown]
# # 20-12.크롤링 이용하기 (3) 로그인하기

# %%
#세션 생성하기
session = requests.session()

#로그인하기
log_info = {'id':'', #여러분의 ID와 PW를 입력해 주세요
            'pw':''}
url = 'https://nid.naver.com/nidlogin.login'
response = session.post(url, data=log_info)

#마이페이지 접근하기
url_mypage = 'https://nid.naver.com/user2/help/myInfo.nhn?lang=ko_KR'
response = session.get(url_mypage)

#Soup객체 생성
soup = BeautifulSoup(response.text, 'html.parser')

#마이페이지에 별명 가져 오기
soup.find('span')
# Out:
# <span>본문으로 바로가기</span>

# %% [markdown]
# これはできない例を与えたコード

# %% [markdown]
# # 20-13.크롤링 이용하기 (4) 브라우저 제어를 통한 크롤링

# %%
# !conda install selenium -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/thuban/anaconda3/envs/aiffel
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     selenium-3.141.0           |py37h14c3975_1001         811 KB
#     ------------------------------------------------------------
#                                            Total:         811 KB
#
# The following NEW packages will be INSTALLED:
#
#   selenium           pkgs/main/linux-64::selenium-3.141.0-py37h14c3975_1001
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.1.19-h06a4308_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2020.12.5-py37h8~ --> pkgs/main::certifi-2020.12.5-py37h06a4308_0
#   openssl            conda-forge::openssl-1.1.1i-h7f98852_0 --> pkgs/main::openssl-1.1.1i-h27cfd23_0
#
#
#
# Downloading and Extracting Packages
# selenium-3.141.0     | 811 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
crawling_urls = {
"산과공원": "https://data.seoul.go.kr/dataList/OA-12962/S/1/datasetView.do",
}

# %%
import requests
from selenium import webdriver
import time
import pandas as pd
import os
import os.path
import glob

# %%
wd_path ='./chromedriver'

#웹드라이버 실행 및 페이지 이동
driver = webdriver.Chrome(wd_path)   # 크롬드라이버를 통해 브라우저를 띄우고
driver.get(crawling_urls['산과공원'])      # 우리가 원하는 URL로 이동합니다.
time.sleep(5)       # 해당 화면이 다 로딩할 때까지 5초간 충분히 기다려 줍니다. 
    
#csv파일 다운로드 버튼 클릭하기
driver.find_element_by_css_selector("#btnCsv").click()   # 사람이 누른 것처럼 다운로드 버튼을 클릭한 후
time.sleep(3)     # 다운로드가 완료될 때까지 3초간 기다려 줍니다. 

driver.quit()      # 브라우저를 닫습니다.

# %%
#다운받은 csv파일 확인
_dir = os.getenv('HOME')+'/다운로드'
#_dir = os.getenv('HOME')+'/Downloads'   # 영문 우분투 사용자라면 이 경로를 선택해 주세요.

files = glob.glob('{}/서울시*.csv'.format(_dir))
print(files)
# Out:
# ['/home/thuban/다운로드/서울시 산과공원 생태관광 정보 (한국어).csv']

# %%
#csv파일을 dataframe으로 변환하기
#인코딩 에러 발생시에 encoding옵션 추가
f_M_park = pd.read_csv(files[0], encoding='CP949')   #CP949: windows에서 사용하는 인코딩 방식
f_M_park.head(3)
# Out:
#               키             명칭   대분류  \
# 0  BE_IW14-0020  진관내동 생태경관보전지역  생태탐방
# 1  BE_IW14-0109           안산공원  산과공원
# 2  BE_IW14-0110          여의도공원  산과공원
#
#                                            주소   행정 시  행정 구  행정 동  \
# 0  은평구 진관동 282-1번지 일대(북한산국립공원 북한산성 입구 주변 습지 )  서울특별시   은평구   진관동
# 1                     서울특별시 서대문구 홍제동 산33번지 일대  서울특별시  서대문구  홍제1동
# 2                서울특별시 영등포구 여의공원로68(여의도동 2번지)  서울특별시  영등포구   여의동
#
#                          대표전화      면적            지정일  \
# 0  02-2115-7550~5 02-350-1397  16639㎡  2002년 12월 30일
# 1                 02-330-1395     NaN            NaN
# 2                 02-761-4079     NaN            NaN
#
#                                                 교?안내
# 0  지하철 3호선 구파발역 1번 출구에서 704번 34번 버스를 타고 북한산성 입구에서...
# 1                                                NaN
# 2                                                NaN
