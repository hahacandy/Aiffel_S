# %% [markdown]
# # 14-4. 폐렴을 진단해보자(1)

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join('chest_xray')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 25

print(ROOT_PATH)
# Out:
# chest_xray

# %% [markdown]
# sudo find / -type f -name .DS_Store -print -delete
# 이걸 써줘야 기트허브가 자동생성하는 .DS_Store 파일을 삭제함으로 이미지 인줄알고 처리하려는 오류가 없어짐

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
for root, dirs, files in os.walk('/chest_xray/train/*/'):
    for file in files:
        if not file.endswith('.jpg') or file.startswith('.'):
             continue  # Skip!
        print(file.name)

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1083
# Pneumonia images count in training set: 3102

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
#長さを得るためなんですけどtf.data.Dataset.from_tensor_slicesした場合のみ使うのかな

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 14-5. 폐렴을 진단해보자(2)

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.3547 - accuracy: 0.8295 - precision: 0.9578 - recall: 0.8056 - val_loss: 0.7566 - val_accuracy: 0.7452 - val_precision: 0.7452 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.2447 - accuracy: 0.9073 - precision: 0.9672 - recall: 0.9055 - val_loss: 1.1825 - val_accuracy: 0.7462 - val_precision: 0.7462 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.2118 - accuracy: 0.9215 - precision: 0.9730 - recall: 0.9196 - val_loss: 0.1787 - val_accuracy: 0.9221 - val_precision: 0.9074 - val_recall: 0.9974
# Epoch 4/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.1805 - accuracy: 0.9351 - precision: 0.9767 - recall: 0.9348 - val_loss: 0.1179 - val_accuracy: 0.9625 - val_precision: 0.9973 - val_recall: 0.9522
# Epoch 5/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1884 - accuracy: 0.9289 - precision: 0.9768 - recall: 0.9260 - val_loss: 0.3364 - val_accuracy: 0.8875 - val_precision: 1.0000 - val_recall: 0.8492
# Epoch 6/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1649 - accuracy: 0.9401 - precision: 0.9807 - recall: 0.9376 - val_loss: 0.2458 - val_accuracy: 0.8788 - val_precision: 0.8619 - val_recall: 0.9974
# Epoch 7/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1489 - accuracy: 0.9471 - precision: 0.9832 - recall: 0.9448 - val_loss: 0.0975 - val_accuracy: 0.9702 - val_precision: 0.9908 - val_recall: 0.9691
# Epoch 8/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1486 - accuracy: 0.9447 - precision: 0.9808 - recall: 0.9437 - val_loss: 0.1395 - val_accuracy: 0.9548 - val_precision: 0.9946 - val_recall: 0.9445
# Epoch 9/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.1541 - accuracy: 0.9416 - precision: 0.9811 - recall: 0.9392 - val_loss: 0.7053 - val_accuracy: 0.7913 - val_precision: 1.0000 - val_recall: 0.7204
# Epoch 10/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1614 - accuracy: 0.9318 - precision: 0.9796 - recall: 0.9275 - val_loss: 0.0943 - val_accuracy: 0.9635 - val_precision: 0.9625 - val_recall: 0.9897
# Epoch 11/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1286 - accuracy: 0.9521 - precision: 0.9879 - recall: 0.9470 - val_loss: 0.1382 - val_accuracy: 0.9538 - val_precision: 0.9472 - val_recall: 0.9936
# Epoch 12/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1229 - accuracy: 0.9562 - precision: 0.9876 - recall: 0.9529 - val_loss: 0.0924 - val_accuracy: 0.9702 - val_precision: 0.9934 - val_recall: 0.9664
# Epoch 13/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1096 - accuracy: 0.9600 - precision: 0.9873 - recall: 0.9583 - val_loss: 0.0842 - val_accuracy: 0.9731 - val_precision: 0.9782 - val_recall: 0.9858
# Epoch 14/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1268 - accuracy: 0.9514 - precision: 0.9865 - recall: 0.9473 - val_loss: 0.1939 - val_accuracy: 0.9192 - val_precision: 0.9986 - val_recall: 0.8932
# Epoch 15/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.1087 - accuracy: 0.9622 - precision: 0.9894 - recall: 0.9594 - val_loss: 0.1346 - val_accuracy: 0.9471 - val_precision: 0.9986 - val_recall: 0.9304
# Epoch 16/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1128 - accuracy: 0.9602 - precision: 0.9899 - recall: 0.9559 - val_loss: 0.4742 - val_accuracy: 0.8481 - val_precision: 0.9984 - val_recall: 0.7974
# Epoch 17/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0820 - accuracy: 0.9701 - precision: 0.9944 - recall: 0.9653 - val_loss: 0.0833 - val_accuracy: 0.9750 - val_precision: 0.9960 - val_recall: 0.9703
# Epoch 18/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1017 - accuracy: 0.9643 - precision: 0.9900 - recall: 0.9615 - val_loss: 0.1404 - val_accuracy: 0.9452 - val_precision: 0.9986 - val_recall: 0.9279
# Epoch 19/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0922 - accuracy: 0.9650 - precision: 0.9920 - recall: 0.9605 - val_loss: 0.1384 - val_accuracy: 0.9462 - val_precision: 0.9986 - val_recall: 0.9292
# Epoch 20/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0801 - accuracy: 0.9686 - precision: 0.9940 - recall: 0.9635 - val_loss: 0.0629 - val_accuracy: 0.9788 - val_precision: 0.9974 - val_recall: 0.9743
# Epoch 21/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0779 - accuracy: 0.9698 - precision: 0.9927 - recall: 0.9664 - val_loss: 0.0808 - val_accuracy: 0.9683 - val_precision: 0.9907 - val_recall: 0.9665
# Epoch 22/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0864 - accuracy: 0.9684 - precision: 0.9910 - recall: 0.9659 - val_loss: 0.1008 - val_accuracy: 0.9635 - val_precision: 0.9986 - val_recall: 0.9523
# Epoch 23/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.0698 - accuracy: 0.9770 - precision: 0.9944 - recall: 0.9746 - val_loss: 0.0668 - val_accuracy: 0.9788 - val_precision: 0.9947 - val_recall: 0.9768
# Epoch 24/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.0760 - accuracy: 0.9725 - precision: 0.9930 - recall: 0.9696 - val_loss: 0.1292 - val_accuracy: 0.9587 - val_precision: 0.9986 - val_recall: 0.9457
# Epoch 25/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0636 - accuracy: 0.9773 - precision: 0.9954 - recall: 0.9738 - val_loss: 0.1272 - val_accuracy: 0.9635 - val_precision: 0.9946 - val_recall: 0.9562

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 61ms/step - loss: 0.6688 - accuracy: 0.8429 - precision: 0.8174 - recall: 0.9641
